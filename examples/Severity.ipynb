# %%
import logging
logging.basicConfig(level=logging.INFO,format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
import os
import geopandas as gpd

from fire_impacts.pre.project import initialise_project, find_all_shapefiles
from fire_impacts.pre.severity import calculate_fire_severity
# Out:
# 2024-09-19 15:46:03,763 - numexpr.utils - INFO - NumExpr defaulting to 16 threads.

# %%
# Define working directory and shapefile path
WORKING_DIRECTORY = './fire-impacts-data'
CATCHMENT_SHAPEFILE_PATH = '' # Set path to catchment boundary shapefiles
FIRE_START_DATE = '2019-01-15'  # Set fire start date (the date that fire started)
FIRE_END_DATE = '2019-03-07'    # Set fire end date (the date that fire ended)

# %%
# Get all shapefiles and bounding boxes
shapefiles = find_all_shapefiles(CATCHMENT_SHAPEFILE_PATH)

# Initialize project folders with exist_ok=True to avoid FileExistsError
project_folders = initialise_project(WORKING_DIRECTORY, catchment_shapefiles=shapefiles, exist_ok=True)

for shapefile_path in shapefiles:
    calculate_fire_severity(
        project=project_folders,
        shapefile_path=shapefile_path,
        fire_start_date=FIRE_START_DATE,
        fire_end_date=FIRE_END_DATE
    )
# Out:
# 2024-09-19 15:46:05,645 - fire_impacts.pre.severity - INFO - No start date for pre-fire data provided. Defaulting to 90 days before fire start date.
# 2024-09-19 15:46:05,647 - fire_impacts.pre.severity - INFO - No end date for post-fire data provided. Defaulting to 90 days after fire end date.
# 2024-09-19 15:46:05,649 - fire_impacts.pre.severity - INFO - Bounding box not provided. Calculating bounding box from shapefile with 10km buffer.
# 2024-09-19 15:46:05,921 - fire_impacts.pre.severity - INFO - Calculating Pre_fire NBR for DR_Primary_Catchment_Thomson
# 2024-09-19 15:46:06,064 - fire_impacts.pre.severity - INFO - Found: 8 datasets
# 2024-09-19 15:46:29,171 - fire_impacts.pre.severity - INFO - Calculating Post_fire NBR for DR_Primary_Catchment_Thomson
# 2024-09-19 15:46:29,308 - fire_impacts.pre.severity - INFO - Found: 9 datasets
# 2024-09-19 15:46:49,861 - fire_impacts.pre.severity - INFO - Calculating dNBR for DR_Primary_Catchment_Thomson
# 2024-09-19 15:46:49,907 - fire_impacts.pre.severity - INFO - Processes are completed
# 2024-09-19 15:46:49,908 - fire_impacts.pre.severity - INFO - No start date for pre-fire data provided. Defaulting to 90 days before fire start date.
# 2024-09-19 15:46:49,908 - fire_impacts.pre.severity - INFO - No end date for post-fire data provided. Defaulting to 90 days after fire end date.
# 2024-09-19 15:46:49,909 - fire_impacts.pre.severity - INFO - Bounding box not provided. Calculating bounding box from shapefile with 10km buffer.
# 2024-09-19 15:46:50,003 - fire_impacts.pre.severity - INFO - Calculating Pre_fire NBR for Upper_Yarra
# 2024-09-19 15:46:50,156 - fire_impacts.pre.severity - INFO - Found: 14 datasets
# 2024-09-19 15:47:20,844 - fire_impacts.pre.severity - INFO - Calculating Post_fire NBR for Upper_Yarra
# 2024-09-19 15:47:20,990 - fire_impacts.pre.severity - INFO - Found: 14 datasets
# 2024-09-19 15:48:03,495 - fire_impacts.pre.severity - INFO - Calculating dNBR for Upper_Yarra
# 2024-09-19 15:48:03,536 - fire_impacts.pre.severity - INFO - Processes are completed
